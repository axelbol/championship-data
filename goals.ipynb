# %%
# pandas
import pandas as pd

# %% [markdown]
# ### Goals

# %%
df = pd.read_csv(r"C:\Users\axel_\Documents\Python\championship-data\goals\csv\awayScorers.csv", engine="python", header=None)
df.head(2)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = pd.read_csv(r"C:\Users\axel_\Documents\Python\championship-data\goals\csv\awayScorers.csv", engine="python", header=None)
#       2 df.head(2)
#
# ...

# %%
# clean headers
# Make row 0 the column names
df.columns = df.iloc[0]  # Set first row as headers
df = df[1:].reset_index(drop=True)  # Remove that row from data

df.head(2)
# Out:
# 0                            reactKey timeStr  type time overloadTime  \
# 0  1297105855Goal1113816undefinedtrue      55  Goal   55          NaN
# 1  1297358690Goal1056689undefinedtrue  90 + 4  Goal   90          4.0
#
# 0   eventId                                             player homeScore  \
# 0  12971058  {'id': 1113816, 'name': 'Jay Stansfield', 'pro...         0
# 1  12973586  {'id': 1056689, 'name': 'Harvey Knibbs', 'prof...         0
#
# 0 awayScore                       profileUrl  ... penShootoutScore  \
# 0         0  /players/1113816/jay-stansfield  ...              NaN
# 1         0   /players/1056689/harvey-knibbs  ...              NaN
#
# 0                                       shotmapEvent assistStr  \
# 0  {'id': 2832725405, 'eventType': 'Goal', 'teamI...       NaN
# 1  {'id': 2832932071, 'eventType': 'Goal', 'teamI...       NaN
#
# 0 assistProfileUrl assistPlayerId assistKey assistInput goal_scorer  \
# ...

# %%
# list headers
df.columns
# Out:
# Index(['reactKey', 'timeStr', 'type', 'time', 'overloadTime', 'eventId',
#        'player', 'homeScore', 'awayScore', 'profileUrl', 'overloadTimeStr',
#        'isHome', 'ownGoal', 'goalDescription', 'goalDescriptionKey', 'suffix',
#        'suffixKey', 'isPenaltyShootoutEvent', 'nameStr', 'firstName',
#        'lastName', 'fullName', 'playerId', 'newScore', 'penShootoutScore',
#        'shotmapEvent', 'assistStr', 'assistProfileUrl', 'assistPlayerId',
#        'assistKey', 'assistInput', 'goal_scorer', 'matchRound', 'HomeTeamId'],
#       dtype='object', name=0)

# %%
# iloc & loc examples
# df.iloc[0:3]

df.loc[df['time'] == '90']
# Out:
# 0                              reactKey  timeStr  type time overloadTime  \
# 1    1297358690Goal1056689undefinedtrue   90 + 4  Goal   90          4.0
# 2     1297348890Goal435513undefinedtrue       90  Goal   90          NaN
# 3     1297357590Goal215387undefinedtrue   90 + 6  Goal   90          6.0
# 8    1297639090Goal1203658undefinedtrue   90 + 5  Goal   90          5.0
# 9     1297643890Goal812982undefinedtrue   90 + 9  Goal   90          9.0
# 19    1299861390Goal791416undefinedtrue   90 + 5  Goal   90          5.0
# 29    1300827790Goal509151undefinedtrue   90 + 3  Goal   90          3.0
# 51   1304832190Goal1601917undefinedtrue   90 + 7  Goal   90          7.0
# 57    1305156690Goal914402undefinedtrue  90 + 16  Goal   90         16.0
# 73    1309802590Goal848268undefinedtrue   90 + 6  Goal   90          6.0
# 80    1312880290Goal768635undefinedtrue   90 + 4  Goal   90          4.0
# 86   1313267790Goal1286796undefinedtrue   90 + 4  Goal   90          4.0
# ...

# %%
# read each column
df['HomeTeamId'][0:5]
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3    Damion Downs
# 4            8549
# Name: HomeTeamId, dtype: object

# %%
# describing data
df.describe()
# Out:
# 0                                 reactKey timeStr  type time overloadTime  \
# count                                  423     423   423  423           42
# unique                                 423     104     1   89           11
# top     1297105855Goal1113816undefinedtrue      40  Goal   90          4.0
# freq                                     1      11   423   31            9
#
# 0        eventId                                             player homeScore  \
# count        423                                                423       423
# unique       423                                                218         7
# top     12971058  {'id': 1089645, 'name': 'Jaden Philogene-Bidac...         0
# freq           1                                                  9       237
#
# 0      awayScore                               profileUrl  ...  \
# count        423                                      423  ...
# unique         6                                      218  ...
# ...

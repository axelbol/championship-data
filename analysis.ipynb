# %%
# pandas
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\axel_\Documents\Python\championship-data\goals\csv\homeScorers.csv", engine="python", header=None)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv(r"C:\Users\axel_\Documents\Python\championship-data\goals\csv\homeScorers.csv", engine="python", header=None)
#       2 df
#
# ...

# %%
df = pd.read_csv('/home/axel/Code/Python/championship/goals/csv/awayScorers1.csv')
df
# Out:
#                                 reactKey timeStr  type  time  overloadTime  \
# 0     1297131890Goal750033undefinedfalse  90 + 5  Goal    90           5.0
# 1     1297260422Goal465909undefinedfalse      22  Goal    22           NaN
# 2    1297492451Goal1203447undefinedfalse      51  Goal    51           NaN
# 3     1297579583Goal823127undefinedfalse      83  Goal    83           NaN
# 4    1297454338Goal1265460undefinedfalse      38  Goal    38           NaN
# ..                                   ...     ...   ...   ...           ...
# 323   135512304Goal1198007undefinedfalse       4  Goal     4           NaN
# 324   1355143622Goal700683undefinedfalse      22  Goal    22           NaN
# 325    135535577Goal302241undefinedfalse       7  Goal     7           NaN
# 326   1355362515Goal302241undefinedfalse      15  Goal    15           NaN
# 327   1355372424Goal759801undefinedfalse      24  Goal    24           NaN
#
# ...

# %%
import pandas as pd

df = pd.read_csv('/home/axel/Code/Python/championship/goals/csv/awayScorers.csv')

# Create a dictionary mapping old column names to blank strings
headers_to_blank = ['Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33']
rename_dict = {col: '' for col in headers_to_blank if col in df.columns}

# Rename the columns
df.rename(columns=rename_dict, inplace=True)

# Save to CSV
df.to_csv('/home/axel/Code/Python/championship/goals/csv/awayScorers1.csv', index=False)

# %%
import csv

with open("/home/axel/Code/Python/championship/goals/csv/awayScorers.csv", newline="", encoding="utf-8") as f:
    reader = csv.reader(f)
    header = next(reader)

# %%
idx = header.index("assistProfileUrl")

new_header = (
    header[:idx + 1]
    + ["assistPlayerId", "assistKey", "assistInput"]
    + header[idx + 1:]
)

print(len(new_header))  # should be 34
# Out:
# 37

# %%
import pandas as pd

df = pd.read_csv(
    "/home/axel/Code/Python/championship/goals/csv/awayScorers.csv",
    skiprows=1,          # skip original header
    names=new_header,    # force 34 columns
    engine="python"      # required
)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv(
#       4     "/home/axel/Code/Python/championship/goals/csv/awayScorers.csv",
#       5     skiprows=1,          # skip original header
#       6     names=new_header,    # force 34 columns
#       7     engine="python"      # required
#       8 )
#
# ...

# %%
df.to_csv(
    "/home/axel/Code/Python/championship/goals/csv/TESTNEWawayScorers.csv",
    index=False,
    encoding="utf-8"
)

# %%
Newdf = pd.read_csv('/home/axel/Code/Python/championship/goals/csv/TESTNEWawayScorers.csv')
Newdf
# Out:
#                               reactKey  timeStr  type  time  overloadTime  \
# 0   1353792471Goal150591undefinedfalse       71  Goal    71           NaN
# 1   1353478244Goal798654undefinedfalse       44  Goal    44           NaN
# 2  1355090827Goal1439800undefinedfalse       27  Goal    27           NaN
#
#     eventId                                             player  homeScore  \
# 0  13537924  {'id': 150591, 'name': 'Liam Cooper', 'profile...          2
# 1  13534782  {'id': 798654, 'name': 'Ephron Mason-Clark', '...          0
# 2  13550908  {'id': 1439800, 'name': 'Patrick Agyemang', 'p...          0
#
#    awayScore                          profileUrl  ...  penShootoutScore  \
# 0          0         /players/150591/liam-cooper  ...               NaN
# 1          0  /players/798654/ephron-mason-clark  ...               NaN
# 2          0   /players/1439800/patrick-agyemang  ...               NaN
#
#                                         shotmapEvent  \
# ...

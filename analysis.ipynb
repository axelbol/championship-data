# %%
# pandas
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\axel_\Documents\Python\championship-data\goals\csv\homeScorers.csv", engine="python", header=None)
df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.read_csv(r"C:\Users\axel_\Documents\Python\championship-data\goals\csv\homeScorers.csv", engine="python", header=None)
#       2 df
#
# ...

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\axel_\Documents\Python\championship-data\goals\csv\homeScorers.csv")      # or pd.read_csv
df.columns = [
    f"col_{i}" if str(col).startswith("Unnamed") else col
    for i, col in enumerate(df.columns)
]
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[18], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv(r"C:\Users\axel_\Documents\Python\championship-data\goals\csv\homeScorers.csv")      # or pd.read_csv
#       4 df.columns = [
#       5     f"col_{i}" if str(col).startswith("Unnamed") else col
#       6     for i, col in enumerate(df.columns)
#       7 ]
#
# ...

# %%
with open(r"C:\Users\axel_\Documents\Python\championship-data\goals\csv\homeScorers.csv", encoding="utf-8") as f:
    for i, line in enumerate(f, start=1):
        if i in bad.index:   # print only the problematic rows
            print(f"Row {i}: {line}")
# Out:
# Row 1: reactKey,timeStr,type,time,overloadTime,eventId,player,homeScore,awayScore,profileUrl,overloadTimeStr,isHome,ownGoal,goalDescription,goalDescriptionKey,suffix,suffixKey,isPenaltyShootoutEvent,nameStr,firstName,lastName,fullName,playerId,newScore,penShootoutScore,shotmapEvent,assistStr,assistProfileUrl,goal_scorer,matchRound,HomeTeamId
#
# ...
